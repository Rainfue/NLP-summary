# %% [markdown]
# # **Модуль Г.** Презентация решения

# %% [markdown]
# В этом модуле была выполнена презентация, в которой отражены все аспекты работы
#
# А также, презентация была представлена экспертам (защита решения)
